# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# Requirement already satisfied: nltk in /Users/msawant/Library/Python/3.9/lib/python/site-packages (3.9.1)
# Requirement already satisfied: joblib in /Users/msawant/Library/Python/3.9/lib/python/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: tqdm in /Users/msawant/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: click in /Users/msawant/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /Users/msawant/Library/Python/3.9/lib/python/site-packages (from nltk) (2024.11.6)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/msawant/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/msawant/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,f1_score, precision_score, recall_score

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# Requirement already satisfied: openpyxl in /Users/msawant/Library/Python/3.9/lib/python/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/msawant/Library/Python/3.9/lib/python/site-packages (from openpyxl) (2.0.0)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: Ignoring invalid distribution -andas (/Users/msawant/Library/Python/3.9/lib/python/site-packages)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
#file_path = "EXIST_2023/disagreement_records_task1.xlsx"
file_path="EXIST_2023/EXIST2023_Task1_age.xlsx"
data = pd.read_excel(file_path)

# %%
len(data)
# Out:
# 3260

# %%
data.head(20)
# Out:
#     Unnamed: 0      id                                              tweet  \
# 0            0  200001  FFS! How about laying the blame on the bastard...
# 1            1  200002  Writing a uni essay in my local pub with a cof...
# 2            2  200003  @UniversalORL it is 2021 not 1921. I dont appr...
# 3            3  200004  @GMB this is unacceptable. Use her title as yo...
# 4            4  200005  ‘Making yourself a harder target’ basically bo...
# 5            5  200006  According to a customer I have plenty of time ...
# 6            6  200007  So only 'blokes' drink beer? Sorry, but if you...
# 7            7  200008  New to the shelves this week - looking forward...
# 8            8  200009  #EverydaySexism We can &amp; need to do better...
# 9            9  200010  I guess that’s fairly normal for a Neanderthal...
# 10          10  200011  #EverydaySexism means women usually end up in ...
# 11          11  200012  I actually had an email from Liz Truss today. ...
# 12          12  200013  @orlamuldoon @NWCI @IrishRunnerMag @ReclaimTS ...
# 13          13  200014  For yourself of course. Let's start with the s...
# 14          14  200015  @MarkPaulTimes @colettebrowne #EveryDaySexism ...
# 15          15  200016  @RMatthewsPsyEdu @ITV @jamesmartinchef @Everyd...
# 16          16  200017  @Geek_Pride @kathrynstimpson @medicalpoke @Eve...
# 17          17  200018  February 28, 2022: Daily Mail website voyeuris...
# 18          18  200019  Sorry. My feminist rage at the old white man p...
# 19          19  200020  Why do we create comics about sexism in scienc...
#
#     number_annotators                                         annotators  \
# 0                   6  ['Annotator_391', 'Annotator_392', 'Annotator_...
# 1                   6  ['Annotator_391', 'Annotator_392', 'Annotator_...
# 2                   6  ['Annotator_397', 'Annotator_398', 'Annotator_...
# 3                   6  ['Annotator_403', 'Annotator_404', 'Annotator_...
# 4                   6  ['Annotator_409', 'Annotator_410', 'Annotator_...
# 5                   6  ['Annotator_409', 'Annotator_410', 'Annotator_...
# 6                   6  ['Annotator_415', 'Annotator_416', 'Annotator_...
# 7                   6  ['Annotator_420', 'Annotator_296', 'Annotator_...
# 8                   6  ['Annotator_425', 'Annotator_426', 'Annotator_...
# 9                   6  ['Annotator_431', 'Annotator_432', 'Annotator_...
# 10                  6  ['Annotator_437', 'Annotator_438', 'Annotator_...
# 11                  6  ['Annotator_443', 'Annotator_444', 'Annotator_...
# 12                  6  ['Annotator_449', 'Annotator_450', 'Annotator_...
# 13                  6  ['Annotator_455', 'Annotator_456', 'Annotator_...
# 14                  6  ['Annotator_461', 'Annotator_462', 'Annotator_...
# 15                  6  ['Annotator_467', 'Annotator_468', 'Annotator_...
# 16                  6  ['Annotator_473', 'Annotator_474', 'Annotator_...
# 17                  6  ['Annotator_478', 'Annotator_479', 'Annotator_...
# 18                  6  ['Annotator_484', 'Annotator_485', 'Annotator_...
# 19                  6  ['Annotator_461', 'Annotator_462', 'Annotator_...
#
#                  gender_annotators  \
# 0   ['F', 'F', 'M', 'M', 'M', 'F']
# 1   ['F', 'F', 'M', 'M', 'M', 'F']
# 2   ['F', 'F', 'M', 'M', 'M', 'F']
# 3   ['F', 'F', 'M', 'M', 'M', 'F']
# 4   ['F', 'F', 'M', 'M', 'M', 'F']
# 5   ['F', 'F', 'M', 'M', 'M', 'F']
# 6   ['F', 'F', 'M', 'M', 'M', 'F']
# 7   ['F', 'F', 'M', 'M', 'M', 'F']
# 8   ['F', 'F', 'M', 'M', 'M', 'F']
# 9   ['F', 'F', 'M', 'M', 'M', 'F']
# 10  ['F', 'F', 'M', 'M', 'M', 'F']
# 11  ['F', 'F', 'M', 'M', 'M', 'F']
# 12  ['F', 'F', 'M', 'M', 'M', 'F']
# 13  ['F', 'F', 'M', 'M', 'M', 'F']
# 14  ['F', 'F', 'M', 'M', 'M', 'F']
# 15  ['F', 'F', 'M', 'M', 'M', 'F']
# 16  ['F', 'F', 'M', 'M', 'M', 'F']
# 17  ['F', 'F', 'M', 'M', 'M', 'F']
# 18  ['F', 'F', 'M', 'M', 'M', 'F']
# 19  ['F', 'F', 'M', 'M', 'M', 'F']
#
#                                        age_annotators  \
# 0   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 1   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 2   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 3   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 4   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 5   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 6   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 7   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 8   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 9   ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 10  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 11  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 12  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 13  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 14  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 15  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 16  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 17  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 18  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
# 19  ['18-22', '23-45', '18-22', '23-45', '46+', '4...
#
#                                   labels_task1  Total_vote  Total_age1  \
# 0      ['YES', 'YES', 'NO', 'NO', 'YES', 'NO']           3           1
# 1    ['YES', 'YES', 'YES', 'NO', 'YES', 'YES']           5           2
# 2     ['YES', 'YES', 'NO', 'YES', 'NO', 'YES']           4           1
# 3      ['YES', 'YES', 'NO', 'YES', 'NO', 'NO']           3           1
# 4      ['YES', 'YES', 'NO', 'NO', 'NO', 'YES']           3           1
# 5   ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 6   ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 7        ['NO', 'NO', 'NO', 'YES', 'NO', 'NO']           1           0
# 8      ['YES', 'YES', 'NO', 'NO', 'YES', 'NO']           3           1
# 9        ['NO', 'NO', 'NO', 'NO', 'YES', 'NO']           1           0
# 10  ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 11     ['YES', 'NO', 'YES', 'NO', 'NO', 'YES']           3           2
# 12    ['YES', 'NO', 'YES', 'YES', 'YES', 'NO']           4           2
# 13     ['YES', 'NO', 'YES', 'NO', 'YES', 'NO']           3           2
# 14  ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 15  ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 16    ['YES', 'YES', 'NO', 'YES', 'NO', 'YES']           4           1
# 17    ['YES', 'NO', 'YES', 'YES', 'NO', 'YES']           4           2
# 18  ['YES', 'YES', 'YES', 'YES', 'YES', 'YES']           6           2
# 19   ['YES', 'YES', 'YES', 'YES', 'NO', 'YES']           5           2
#
#     Total_age2  Total_age3  majority_vote  age1_vote  age2_vote  age3_vote
# 0            1           1              1          0          0          0
# 1            1           2              1          1          0          1
# 2            2           1              1          0          1          0
# 3            2           0              1          0          1          0
# 4            1           1              1          0          0          0
# 5            2           2              1          1          1          1
# 6            2           2              1          1          1          1
# 7            1           0              0          0          0          0
# 8            1           1              1          0          0          0
# 9            0           1              0          0          0          0
# 10           2           2              1          1          1          1
# 11           0           1              1          1          0          0
# 12           1           1              1          1          0          0
# 13           0           1              1          1          0          0
# 14           2           2              1          1          1          1
# 15           2           2              1          1          1          1
# 16           2           1              1          0          1          0
# 17           1           1              1          1          0          0
# 18           2           2              1          1          1          1
# 19           2           1              1          1          1          0

# %%
import re

def remove_urls_and_lower(text):
    # Define the regex pattern for URLs starting with http or https
    url_pattern = re.compile(r'http[s]?://\S+')
    # Substitute the URLs with an empty string
    cleaned_text = url_pattern.sub('', text)
    cleaned_text = cleaned_text.lower()
    return cleaned_text.strip()

# %%
def clean_text(text):
    return re.sub(r'[^A-Za-z\s]', '', text) if isinstance(text, str) else text
    #return re.sub(r'[^A-Za-z0-9\s]', '', text) if isinstance(text, str) else text

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
#additional_stopwords={'ago','also','along','always','amp','like','look','know','even','want','say','get','far','use','take','never','great','whole','know','even','use','take','would'}
stop_words.update(['ago','also','along','always','amp','like','look','know','even','want','say','get','far','use','take','never','great','whole','would','ok','dont','cant','shes','theyre','without','youre','isnt','us','yet','yall','u','id'])


#stop_words.update(['ago','also','along','always','amp','like','look','know','even','want','say','get','far','use','take','never','great','whole','would','ok','dont','cant','shes','theyre','without','youre'])

def stopwords_removal(text):
    words=word_tokenize(text)
    filtered_words=[w for w in words if w.lower() not in stop_words]
    return ' '.join(filtered_words)

# %%
from nltk.corpus import wordnet
def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

# %%
from nltk.stem import WordNetLemmatizer
def apply_lemmatization(text):
    pos_tagged = nltk.pos_tag(nltk.word_tokenize(text))  
    wordnet_tagged = list(map(lambda x: (x[0], pos_tagger(x[1])), pos_tagged))
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            # if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:        
        # else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    lemmatized_sentence = " ".join(lemmatized_sentence)
    return lemmatized_sentence

# %%
tweet_processed=data["tweet"].apply(remove_urls_and_lower)
tweet_processed=tweet_processed.apply(clean_text)
tweet_processed=tweet_processed.apply(apply_lemmatization)
tweet_processed=tweet_processed.apply(stopwords_removal)

# %%
vec=TfidfVectorizer(tokenizer=word_tokenize,token_pattern=None,ngram_range=(1,1))
tweet_vectorized=vec.fit_transform(tweet_processed)

# %% [markdown]
# Train Model for Majority vote

# %%
X_train, X_test, y_train, y_test = train_test_split(tweet_vectorized,data["majority_vote"], test_size=0.30, random_state=0)

# %%
rf_model=RandomForestClassifier(bootstrap=False, min_samples_leaf=4,min_samples_split=10,n_estimators=100,n_jobs=-1,random_state=10)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_leaf=4,
#                        min_samples_split=10, n_jobs=-1, random_state=10)

# %%
y_pred_rf =rf_model.predict(X_test)
y_pred_rf = y_pred_rf.astype(int)
accuracy= accuracy_score(y_test,y_pred_rf)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred_rf))
f1=f1_score(y_test,y_pred_rf,average='macro')
print(f"F1 score:{f1}")

# Calculate Precision and Recall
precision = precision_score(y_test, y_pred_rf, average='macro')
recall = recall_score(y_test, y_pred_rf, average='macro')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# ACCURACY OF THE MODEL: 0.7576687116564417
# F1 score:0.7567835568198631
# Precision: 0.7572300501059286
# Recall: 0.7565302144249513

# %%
target_names = ['Yes','No']
print(classification_report(y_test, y_pred_rf, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.76      0.78      0.77       513
#           No       0.75      0.73      0.74       465
#
#     accuracy                           0.76       978
#    macro avg       0.76      0.76      0.76       978
# weighted avg       0.76      0.76      0.76       978

# %% [markdown]
# Trained Model for Age1 Vote

# %%
X_train, X_test, y_train, y_test = train_test_split(tweet_vectorized,data["age1_vote"], test_size=0.30, random_state=0)

# %%
rf_model=RandomForestClassifier(bootstrap=False, min_samples_leaf=4,min_samples_split=10,n_estimators=100,n_jobs=-1,random_state=10)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_leaf=4,
#                        min_samples_split=10, n_jobs=-1, random_state=10)

# %%
y_pred_rf =rf_model.predict(X_test)
y_pred_rf = y_pred_rf.astype(int)
accuracy= accuracy_score(y_test,y_pred_rf)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred_rf))
f1=f1_score(y_test,y_pred_rf,average='macro')
print(f"F1 score:{f1}")

# Calculate Precision and Recall
precision = precision_score(y_test, y_pred_rf, average='macro')
recall = recall_score(y_test, y_pred_rf, average='macro')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# ACCURACY OF THE MODEL: 0.7648261758691206
# F1 score:0.4964270363206533
# Precision: 0.6519886363636364
# Recall: 0.5265843117315336

# %%
target_names = ['Yes','No']
print(classification_report(y_test, y_pred_rf, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.77      0.98      0.86       746
#           No       0.53      0.07      0.13       232
#
#     accuracy                           0.76       978
#    macro avg       0.65      0.53      0.50       978
# weighted avg       0.72      0.76      0.69       978

# %% [markdown]
# Trained Model for age2 Vote

# %%
X_train, X_test, y_train, y_test = train_test_split(tweet_vectorized,data["age2_vote"], test_size=0.30, random_state=0)

# %%
rf_model=RandomForestClassifier(bootstrap=False, min_samples_leaf=4,min_samples_split=10,n_estimators=100,n_jobs=-1,random_state=10)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_leaf=4,
#                        min_samples_split=10, n_jobs=-1, random_state=10)

# %%
y_pred_rf =rf_model.predict(X_test)
y_pred_rf = y_pred_rf.astype(int)
accuracy= accuracy_score(y_test,y_pred_rf)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred_rf))
f1=f1_score(y_test,y_pred_rf,average='macro')
print(f"F1 score:{f1}")

# Calculate Precision and Recall
precision = precision_score(y_test, y_pred_rf, average='macro')
recall = recall_score(y_test, y_pred_rf, average='macro')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# ACCURACY OF THE MODEL: 0.7484662576687117
# F1 score:0.5848266055552488
# Precision: 0.7202654082803213
# Recall: 0.5868293936279547

# %%
target_names = ['Yes','No']
print(classification_report(y_test, y_pred_rf, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.75      0.96      0.85       700
#           No       0.69      0.21      0.32       278
#
#     accuracy                           0.75       978
#    macro avg       0.72      0.59      0.58       978
# weighted avg       0.74      0.75      0.70       978

# %% [markdown]
# Trained model for age3 vote

# %%
X_train, X_test, y_train, y_test = train_test_split(tweet_vectorized,data["age3_vote"], test_size=0.30, random_state=0)

# %%
rf_model=RandomForestClassifier(bootstrap=False, min_samples_leaf=4,min_samples_split=10,n_estimators=100,n_jobs=-1,random_state=10)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_leaf=4,
#                        min_samples_split=10, n_jobs=-1, random_state=10)

# %%
y_pred_rf =rf_model.predict(X_test)
y_pred_rf = y_pred_rf.astype(int)
accuracy= accuracy_score(y_test,y_pred_rf)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred_rf))
f1=f1_score(y_test,y_pred_rf,average='macro')
print(f"F1 score:{f1}")

# Calculate Precision and Recall
precision = precision_score(y_test, y_pred_rf, average='macro')
recall = recall_score(y_test, y_pred_rf, average='macro')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# ACCURACY OF THE MODEL: 0.745398773006135
# F1 score:0.5657929224399698
# Precision: 0.7310415355569541
# Recall: 0.5752995831218176

# %%
target_names = ['Yes','No']
print(classification_report(y_test, y_pred_rf, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.75      0.97      0.85       699
#           No       0.71      0.18      0.29       279
#
#     accuracy                           0.75       978
#    macro avg       0.73      0.58      0.57       978
# weighted avg       0.74      0.75      0.69       978
